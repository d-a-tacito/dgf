# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
n_samples = 250

# %%
# Вариант 1
X = np.random.rand(n_samples, 2)
Y = (((2*X[:, 0]-0.7))+(-X[:, 1]+0.1) < 0.1)

# %%
# Вариант 2
X = np.random.rand(n_samples, 2)
Y = (((2*X[:, 0]-0.7))+(-0.5*X[:, 1]+0.1) < 0.1)

# %%
# Вариант 3
X = np.random.rand(n_samples, 2)
Y = (((5*X[:, 0]-0.9))+(-0.5*X[:, 1]+0.1) < 0.5)

# %%
# Вариант 4
X = np.random.rand(n_samples, 2)
Y = (((5*X[:, 0]-0.9))+(-4*X[:, 1]-0.1) > 0.5)

# %%
# Вариант 5
X = np.random.rand(n_samples, 2)
Y = (((3*X[:, 0]-0.9))+(0.5*X[:, 1]-0.3) < 0.5)

# %%
# Вариант 6
X = np.random.rand(n_samples, 2)
Y = (((3*X[:, 0]-0.9))+(0.5*X[:, 1]-0.3) < 0.8)

# %%
# Вариант 7
X = np.random.rand(n_samples, 2)
Y = (((3*X[:, 0]-0.3))+(-0.5*X[:, 1]-0.3) < 0.5)

# %%
# Вариант 8
X = np.random.rand(n_samples, 2)
Y = (((X[:, 0]))+(0.5*X[:, 1]-0.3) < 0.4)

# %%
# Вариант 9
X = np.random.rand(n_samples, 2)
Y = (((X[:, 0]-0.9))+(X[:, 1]-0.3) < 0)

# %%
# Вариант 10
X = np.random.rand(n_samples, 2)
Y = (((3*X[:, 0]-0.5))+(2*X[:, 1]-0.1) < 1.5)

# %%
# Вариант 11
X = np.random.rand(n_samples, 2)
Y = (((X[:, 0]-0.9))+(2*X[:, 1]-0.3) < 0.2)

# %%
# Вариант 12
X = np.random.rand(n_samples, 2)
Y = (((7*X[:, 0]-3))+(X[:, 1]-0.3) < 0.5)

# %%
# Вариант 13
X = np.random.rand(n_samples, 2)
Y = (((X[:, 0]-0.3))+(0.1*X[:, 1]+0.3) < 0.5)

# %%
# Вариант 14
X = np.random.rand(n_samples, 2)
Y = (((3*X[:, 0]-1.5))+(0.2*X[:, 1]+0.4) < 0.5)

# %%
# Вариант 15
X = np.random.rand(n_samples, 2)
Y = (((5*X[:, 0]-0.5))+(-2*X[:, 1]+0.4) < 0.5)

# %%
# Вариант 16
X = np.random.rand(n_samples, 2)
Y = (((3*X[:, 0]-1))-(-0.1*X[:, 1]-0.4) < 0.7)

# %%
# Вариант 17
X = np.random.rand(n_samples, 2)
Y = (((5*X[:, 0]-1.0))+(-2*X[:, 1]-0.4) < 0.5)

# %%
# Вариант 18
X = np.random.rand(n_samples, 2)
Y = (((3*X[:, 0]-1.5))+(-0.8*X[:, 1]+0.4) < 0.3)

# %%
#Вариант 19
X = np.random.rand(n_samples, 2)
Y = (((7*X[:, 0]-0.7))+(-X[:, 1]-0.1) < 2)

# %%
#Вариант 20
X = np.random.rand(n_samples, 2)
Y = (((7*X[:, 0]-4))-(-X[:, 1]-3) > 2)

# %%
#Вариант 21
X = np.random.rand(n_samples, 2)
Y = (((0.7*X[:, 0]+0.9))+(-X[:, 1]) > 0.8)

# %%
#Вариант 22
X = np.random.rand(n_samples, 2)
Y = (((0.7*X[:, 0]+1))+(-X[:, 1]-0.1) > 0.8)

# %%
#Вариант 23
X = np.random.rand(n_samples, 2)
Y = (((0.7*X[:, 0]+0.5))-(-X[:, 1]+0.1) > 1)

# %%
#Вариант 24
X = np.random.rand(n_samples, 2)
Y = (((0.7*X[:, 0]-0.05))-(-X[:, 1]+0.1) < 0.5)
